# %%
import pandas as pd 
import numpy as np                     # For mathematical calculations 
import seaborn as sns                  # For data visualization 
import matplotlib.pyplot as plt        # For plotting graphs 
# %matplotlib inline 
import warnings                        # To ignore any warnings warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('ds_salaries.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df_ori = df
df.dtypes
# Out:
# Unnamed: 0             int64
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
df = df_ori
df = df.drop('Unnamed: 0',axis = 1)
df = df.drop('salary',axis = 1)
df = df.drop('salary_currency',axis = 1)
df.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
X = df.drop('salary_in_usd',axis=1)
y = df['salary_in_usd']

# %%
# Categorical: Gender | Married |Self_Employed | Credit_History
plt.figure(1)
plt.subplot(421)
df['work_year'].plot(kind = 'hist',color = '#A52A2A',figsize = (20,10))
plt.title('work_year')
plt.xlabel('work_year')

plt.subplot(422)
(df['experience_level'].value_counts()/df.shape[0]).plot(kind = 'barh',color = '#A52A2A',figsize = (40,20))
plt.title('experience_level')
plt.xlabel('experience_level')

plt.subplot(423)
(df['employment_type'].value_counts()/df.shape[0]).plot(kind = 'barh',color = '#A52A2A',figsize = (40,20))
plt.title('employment_type')
plt.xlabel('employment_type')

plt.subplot(424)
(df['job_title'].value_counts()/df.shape[0]).plot(kind = 'barh',color = '#A52A2A',figsize = (40,20))
plt.title('job_title')
plt.xlabel('job_title')

plt.subplot(425)
(df['employee_residence'].value_counts()/df.shape[0]).plot(kind = 'barh',color = '#A52A2A',figsize = (40,20))
plt.title('employee_residence')
plt.xlabel('employee_residence')

plt.subplot(426)
(df['remote_ratio'].value_counts()/df.shape[0]).plot(kind = 'barh',color = '#A52A2A',figsize = (40,20))
plt.title('remote_ratio')
plt.xlabel('remote_ratio')

plt.subplot(427)
(df['company_location'].value_counts()/df.shape[0]).plot(kind = 'barh',color = '#A52A2A',figsize = (40,20))
plt.title('company_location')
plt.xlabel('company_location')

plt.subplot(428)
(df['company_size'].value_counts()/df.shape[0]).plot(kind = 'barh',color = '#A52A2A',figsize = (40,20))
plt.title('company_size')
plt.xlabel('company_size')
#plt.savefig('Loan Prediction_Categorical Variables.jpeg')
plt.show()

# %%
(df['experience_level'].value_counts()/df.shape[0]).plot(kind = 'barh',color = '#A52A2A')
plt.title('experience_level')
plt.xlabel('experience_level')
# Out:
# Text(0.5, 0, 'experience_level')

# %%
(df['job_title'].value_counts()/df.shape[0]).plot(kind = 'barh',color = '#A52A2A',figsize = (40,20))
plt.title('job_title')
plt.xlabel('job_title')
# Out:
# Text(0.5, 0, 'job_title')

# %%
df['job_title'].value_counts()
# Out:
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Science Consultant                       7
# Director of Data Science                      7
# Data Analytics Manager                        7
# ML Engineer                                   6
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# Business Data Analyst                         5
# ...

# %%
(df['company_location'].value_counts()/df.shape[0]).plot(kind = 'barh',color = '#A52A2A',figsize = (40,20))
plt.title('company_location')
plt.xlabel('company_location')
# Out:
# Text(0.5, 0, 'company_location')

# %%
df['company_location'].value_counts()
# Out:
# US    355
# GB     47
# CA     30
# DE     28
# IN     24
# FR     15
# ES     14
# GR     11
# JP      6
# NL      4
# AT      4
# PT      4
# PL      4
# LU      3
# PK      3
# BR      3
# AE      3
# MX      3
# AU      3
# TR      3
# DK      3
# IT      2
# CZ      2
# SI      2
# RU      2
# CH      2
# NG      2
# CN      2
# BE      2
# VN      1
# EE      1
# AS      1
# DZ      1
# MY      1
# MD      1
# KE      1
# SG      1
# CO      1
# IR      1
# CL      1
# MT      1
# IL      1
# UA      1
# IQ      1
# RO      1
# HR      1
# NZ      1
# HU      1
# HN      1
# IE      1
# Name: company_location, dtype: int64

# %%
(df['employee_residence'].value_counts()/df.shape[0]).plot(kind = 'barh',color = '#A52A2A',figsize = (40,20))
plt.title('employee_residence')
plt.xlabel('employee_residence')
# Out:
# Text(0.5, 0, 'employee_residence')

# %%
df['employee_residence'].value_counts()
# Out:
# US    332
# GB     44
# IN     30
# CA     29
# DE     25
# FR     18
# ES     15
# GR     13
# JP      7
# PT      6
# BR      6
# PK      6
# NL      5
# PL      4
# IT      4
# RU      4
# AE      3
# AT      3
# VN      3
# TR      3
# AU      3
# RO      2
# BE      2
# SG      2
# SI      2
# DK      2
# HU      2
# NG      2
# MX      2
# BO      1
# MY      1
# TN      1
# IE      1
# DZ      1
# AR      1
# CZ      1
# JE      1
# LU      1
# PR      1
# RS      1
# EE      1
# CL      1
# HK      1
# KE      1
# MD      1
# CO      1
# IR      1
# CN      1
# MT      1
# UA      1
# IQ      1
# HN      1
# BG      1
# HR      1
# PH      1
# NZ      1
# CH      1
# Name: employee_residence, dtype: int64
